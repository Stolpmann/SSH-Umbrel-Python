# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
import numpy as np

# %%
blockchain = pd.read_csv("blockchain_data.csv")

# %%
blockchain
# Out:
#                       avgfee                 avgfeerate  \
# 0    ['  "avgfee": 4196,\n']   ['  "avgfeerate": 5,\n']
# 1    ['  "avgfee": 6583,\n']  ['  "avgfeerate": 15,\n']
# 2    ['  "avgfee": 1337,\n']   ['  "avgfeerate": 3,\n']
# 3    ['  "avgfee": 4640,\n']  ['  "avgfeerate": 12,\n']
# 4    ['  "avgfee": 5140,\n']  ['  "avgfeerate": 18,\n']
# ..                       ...                        ...
# 95   ['  "avgfee": 6559,\n']  ['  "avgfeerate": 14,\n']
# 96  ['  "avgfee": 18129,\n']  ['  "avgfeerate": 42,\n']
# 97   ['  "avgfee": 4760,\n']  ['  "avgfeerate": 15,\n']
# 98   ['  "avgfee": 3439,\n']   ['  "avgfeerate": 9,\n']
# 99   ['  "avgfee": 6623,\n']  ['  "avgfeerate": 15,\n']
#
#                     avgtxsize  \
# 0   ['  "avgtxsize": 907,\n']
# 1   ['  "avgtxsize": 601,\n']
# 2   ['  "avgtxsize": 511,\n']
# 3   ['  "avgtxsize": 518,\n']
# 4   ['  "avgtxsize": 400,\n']
# ..                        ...
# 95  ['  "avgtxsize": 787,\n']
# 96  ['  "avgtxsize": 670,\n']
# 97  ['  "avgtxsize": 473,\n']
# 98  ['  "avgtxsize": 531,\n']
# 99  ['  "avgtxsize": 689,\n']
#
#                                                                                    blockhash  \
# 0   ['  "blockhash": "00000000000000000009a8a019a7e05cf9dd888543f8e1a5449dea200c3922f5",\n']
# 1   ['  "blockhash": "00000000000000000001dab19d08bf7a5a7dc350855eade998b75d6b74acff05",\n']
# 2   ['  "blockhash": "000000000000000000095b45b8b7acc4e928d7ee0a413fecede707b145d0238b",\n']
# 3   ['  "blockhash": "000000000000000000077ac614d0fa8f6ddd9bea05676d9c7d999308510f1f7d",\n']
# 4   ['  "blockhash": "0000000000000000000bf192140431a034e0ee713a13355bc36d0ec516f16094",\n']
# ..                                                                                       ...
# 95  ['  "blockhash": "00000000000000000008b5cb4d434daa1a70ad860f6be4dda5a8cb8cfad251ef",\n']
# 96  ['  "blockhash": "00000000000000000009a292a55455fe8b857cc8d9dc049bf0f30f42c6610054",\n']
# 97  ['  "blockhash": "00000000000000000004155c8aef586faaa24a7a76498fefe2637218b40e1c2c",\n']
# 98  ['  "blockhash": "00000000000000000008f6309600345615a2f769892ae96b459e816ff235a0dd",\n']
# 99  ['  "blockhash": "0000000000000000000b6b6cbc221f9553aabdc641ca2f8fbe07968386bf6c6b",\n']
#
#                        height                   ins  \
# 0   ['  "height": 703600,\n']   ['  "ins": 917,\n']
# 1   ['  "height": 703601,\n']  ['  "ins": 6180,\n']
# 2   ['  "height": 703602,\n']  ['  "ins": 4026,\n']
# 3   ['  "height": 703603,\n']  ['  "ins": 5778,\n']
# 4   ['  "height": 703604,\n']   ['  "ins": 537,\n']
# ..                        ...                   ...
# 95  ['  "height": 703695,\n']  ['  "ins": 6917,\n']
# 96  ['  "height": 703696,\n']  ['  "ins": 7338,\n']
# 97  ['  "height": 703697,\n']  ['  "ins": 7562,\n']
# 98  ['  "height": 703698,\n']  ['  "ins": 6430,\n']
# 99  ['  "height": 703699,\n']  ['  "ins": 7251,\n']
#
#                         maxfee                  maxfeerate  \
# 0    ['  "maxfee": 236385,\n']  ['  "maxfeerate": 211,\n']
# 1   ['  "maxfee": 2546496,\n']  ['  "maxfeerate": 390,\n']
# 2    ['  "maxfee": 100000,\n']  ['  "maxfeerate": 597,\n']
# 3   ['  "maxfee": 2546496,\n']  ['  "maxfeerate": 371,\n']
# 4    ['  "maxfee": 371800,\n']  ['  "maxfeerate": 260,\n']
# ..                         ...                         ...
# 95  ['  "maxfee": 1051336,\n']  ['  "maxfeerate": 450,\n']
# 96  ['  "maxfee": 8793012,\n']  ['  "maxfeerate": 484,\n']
# 97   ['  "maxfee": 836600,\n']  ['  "maxfeerate": 302,\n']
# 98   ['  "maxfee": 506188,\n']  ['  "maxfeerate": 348,\n']
# 99   ['  "maxfee": 544240,\n']  ['  "maxfeerate": 506,\n']
#
#                        maxtxsize                   medianfee  ...  \
# 0    ['  "maxtxsize": 46682,\n']   ['  "medianfee": 722,\n']  ...
# 1   ['  "maxtxsize": 102640,\n']  ['  "medianfee": 1134,\n']  ...
# 2    ['  "maxtxsize": 29747,\n']   ['  "medianfee": 327,\n']  ...
# 3   ['  "maxtxsize": 102579,\n']   ['  "medianfee": 800,\n']  ...
# 4    ['  "maxtxsize": 10538,\n']   ['  "medianfee": 864,\n']  ...
# ..                           ...                         ...  ...
# 95  ['  "maxtxsize": 214400,\n']  ['  "medianfee": 1540,\n']  ...
# 96  ['  "maxtxsize": 170846,\n']  ['  "medianfee": 2602,\n']  ...
# 97  ['  "maxtxsize": 102800,\n']  ['  "medianfee": 1421,\n']  ...
# 98   ['  "maxtxsize": 34928,\n']  ['  "medianfee": 1130,\n']  ...
# 99  ['  "maxtxsize": 102558,\n']  ['  "medianfee": 1360,\n']  ...
#
#                         swtotal_weight                   swtxs  \
# 0    ['  "swtotal_weight": 146115,\n']   ['  "swtxs": 158,\n']
# 1   ['  "swtotal_weight": 2598714,\n']  ['  "swtxs": 1760,\n']
# 2   ['  "swtotal_weight": 1462988,\n']  ['  "swtxs": 1459,\n']
# 3   ['  "swtotal_weight": 2674590,\n']  ['  "swtxs": 2063,\n']
# 4    ['  "swtotal_weight": 259522,\n']   ['  "swtxs": 247,\n']
# ..                                 ...                     ...
# 95  ['  "swtotal_weight": 3413712,\n']  ['  "swtxs": 1802,\n']
# 96  ['  "swtotal_weight": 3183850,\n']  ['  "swtxs": 1781,\n']
# 97  ['  "swtotal_weight": 3182974,\n']  ['  "swtxs": 2733,\n']
# 98  ['  "swtotal_weight": 3161617,\n']  ['  "swtxs": 2270,\n']
# 99  ['  "swtotal_weight": 3012846,\n']  ['  "swtxs": 1764,\n']
#
#                            time                             total_out  \
# 0   ['  "time": 1633398665,\n']     ['  "total_out": 52374292370,\n']
# 1   ['  "time": 1633400115,\n']   ['  "total_out": 3791679762926,\n']
# 2   ['  "time": 1633400239,\n']   ['  "total_out": 2560378823140,\n']
# 3   ['  "time": 1633401249,\n']   ['  "total_out": 3743004487423,\n']
# 4   ['  "time": 1633401367,\n']    ['  "total_out": 107575540780,\n']
# ..                          ...                                   ...
# 95  ['  "time": 1633449556,\n']  ['  "total_out": 10679600644339,\n']
# 96  ['  "time": 1633451019,\n']   ['  "total_out": 5389401980494,\n']
# 97  ['  "time": 1633451594,\n']   ['  "total_out": 7782147872874,\n']
# 98  ['  "time": 1633451936,\n']    ['  "total_out": 991187484062,\n']
# 99  ['  "time": 1633452664,\n']   ['  "total_out": 5980493496881,\n']
#
#                         total_size                      total_weight  \
# 0    ['  "total_size": 178693,\n']   ['  "total_weight": 632719,\n']
# 1   ['  "total_size": 1401057,\n']  ['  "total_weight": 3996246,\n']
# 2    ['  "total_size": 837850,\n']  ['  "total_weight": 2500480,\n']
# 3   ['  "total_size": 1302513,\n']  ['  "total_weight": 3627402,\n']
# 4    ['  "total_size": 126069,\n']   ['  "total_weight": 353598,\n']
# ..                             ...                               ...
# 95  ['  "total_size": 1749336,\n']  ['  "total_weight": 3996564,\n']
# 96  ['  "total_size": 1553895,\n']  ['  "total_weight": 3991578,\n']
# 97  ['  "total_size": 1538989,\n']  ['  "total_weight": 3991774,\n']
# 98  ['  "total_size": 1501201,\n']  ['  "total_weight": 3991813,\n']
# 99  ['  "total_size": 1568494,\n']  ['  "total_weight": 3997642,\n']
#
#                          totalfee                   txs  \
# 0     ['  "totalfee": 826721,\n']   ['  "txs": 198,\n']
# 1   ['  "totalfee": 15333187,\n']  ['  "txs": 2330,\n']
# 2    ['  "totalfee": 2191189,\n']  ['  "txs": 1639,\n']
# 3   ['  "totalfee": 11665765,\n']  ['  "txs": 2515,\n']
# 4    ['  "totalfee": 1619141,\n']   ['  "txs": 316,\n']
# ..                            ...                   ...
# 95  ['  "totalfee": 14561125,\n']  ['  "txs": 2221,\n']
# 96  ['  "totalfee": 41987952,\n']  ['  "txs": 2317,\n']
# 97  ['  "totalfee": 15462610,\n']  ['  "txs": 3249,\n']
# 98   ['  "totalfee": 9712809,\n']  ['  "txs": 2825,\n']
# 99  ['  "totalfee": 15061361,\n']  ['  "txs": 2275,\n']
#
#                      utxo_increase                    utxo_size_inc
# 0    ['  "utxo_increase": 128,\n']   ['  "utxo_size_inc": 10130\n']
# 1   ['  "utxo_increase": 3183,\n']  ['  "utxo_size_inc": 235899\n']
# 2    ['  "utxo_increase": 469,\n']   ['  "utxo_size_inc": 63565\n']
# 3   ['  "utxo_increase": 1990,\n']  ['  "utxo_size_inc": 166873\n']
# 4    ['  "utxo_increase": 352,\n']   ['  "utxo_size_inc": 29726\n']
# ..                             ...                              ...
# 95  ['  "utxo_increase": -136,\n']   ['  "utxo_size_inc": -6879\n']
# 96   ['  "utxo_increase": 232,\n']   ['  "utxo_size_inc": 18345\n']
# 97   ['  "utxo_increase": 797,\n']   ['  "utxo_size_inc": 62279\n']
# 98  ['  "utxo_increase": 3029,\n']  ['  "utxo_size_inc": 228547\n']
# 99   ['  "utxo_increase": 162,\n']   ['  "utxo_size_inc": 14841\n']
#
# [100 rows x 28 columns]

# %%
blockchain["avgfee"] = blockchain["avgfee"].str.extract('(\d+)', expand=False)
blockchain["avgfeerate"] = blockchain["avgfeerate"].str.extract('(\d+)', expand=False)
blockchain["avgtxsize"] = blockchain["avgtxsize"].str.extract('(\d+)', expand=False)
blockchain["height"] = blockchain["height"].str.extract('(\d+)', expand=False)
blockchain["ins"] = blockchain["ins"].str.extract('(\d+)', expand=False)
blockchain["maxfee"] = blockchain["maxfee"].str.extract('(\d+)', expand=False)
blockchain["maxfeerate"] = blockchain["maxfeerate"].str.extract('(\d+)', expand=False)
blockchain["maxtxsize"] = blockchain["maxtxsize"].str.extract('(\d+)', expand=False)
blockchain["medianfee"] = blockchain["medianfee"].str.extract('(\d+)', expand=False)
blockchain["mediantime"] = blockchain["mediantime"].str.extract('(\d+)', expand=False)
blockchain["mediantxsize"] = blockchain["mediantxsize"].str.extract('(\d+)', expand=False)
blockchain["minfee"] = blockchain["minfee"].str.extract('(\d+)', expand=False)
blockchain["minfeerate"] = blockchain["minfeerate"].str.extract('(\d+)', expand=False)
blockchain["mintxsize"] = blockchain["mintxsize"].str.extract('(\d+)', expand=False)
blockchain["outs"] = blockchain["outs"].str.extract('(\d+)', expand=False)
blockchain["subsidy"] = blockchain["subsidy"].str.extract('(\d+)', expand=False)
blockchain["swtotal_size"] = blockchain["swtotal_size"].str.extract('(\d+)', expand=False)
blockchain["swtotal_weight"] = blockchain["swtotal_weight"].str.extract('(\d+)', expand=False)
blockchain["swtxs"] = blockchain["swtxs"].str.extract('(\d+)', expand=False)
blockchain["time"] = blockchain["time"].str.extract('(\d+)', expand=False)
blockchain["total_out"] = blockchain["total_out"].str.extract('(\d+)', expand=False)
blockchain["total_size"] = blockchain["total_size"].str.extract('(\d+)', expand=False)
blockchain["total_weight"] = blockchain["total_weight"].str.extract('(\d+)', expand=False)
blockchain["totalfee"] = blockchain["totalfee"].str.extract('(\d+)', expand=False)
blockchain["txs"] = blockchain["txs"].str.extract('(\d+)', expand=False)
blockchain["utxo_increase"] = blockchain["utxo_increase"].str.extract('(\d+)', expand=False)
blockchain["utxo_size_inc"] = blockchain["utxo_size_inc"].str.extract('(\d+)', expand=False)

# %%
print(blockchain['blockhash'])
# Out:
# 0     ['  "blockhash": "00000000000000000009a8a019a7e05cf9dd888543f8e1a5449dea200c3922f5",\n']
# 1     ['  "blockhash": "00000000000000000001dab19d08bf7a5a7dc350855eade998b75d6b74acff05",\n']
# 2     ['  "blockhash": "000000000000000000095b45b8b7acc4e928d7ee0a413fecede707b145d0238b",\n']
# 3     ['  "blockhash": "000000000000000000077ac614d0fa8f6ddd9bea05676d9c7d999308510f1f7d",\n']
# 4     ['  "blockhash": "0000000000000000000bf192140431a034e0ee713a13355bc36d0ec516f16094",\n']
#                                                 ...
# 95    ['  "blockhash": "00000000000000000008b5cb4d434daa1a70ad860f6be4dda5a8cb8cfad251ef",\n']
# 96    ['  "blockhash": "00000000000000000009a292a55455fe8b857cc8d9dc049bf0f30f42c6610054",\n']
# 97    ['  "blockhash": "00000000000000000004155c8aef586faaa24a7a76498fefe2637218b40e1c2c",\n']
# 98    ['  "blockhash": "00000000000000000008f6309600345615a2f769892ae96b459e816ff235a0dd",\n']
# 99    ['  "blockhash": "0000000000000000000b6b6cbc221f9553aabdc641ca2f8fbe07968386bf6c6b",\n']
# Name: blockhash, Length: 100, dtype: object

# %%
blockchain["blockhash"] = blockchain["blockhash"].str[18:82]

# %%
print(blockchain['blockhash'])
# Out:
# 0     00000000000000000009a8a019a7e05cf9dd888543f8e1a5449dea200c3922f5
# 1     00000000000000000001dab19d08bf7a5a7dc350855eade998b75d6b74acff05
# 2     000000000000000000095b45b8b7acc4e928d7ee0a413fecede707b145d0238b
# 3     000000000000000000077ac614d0fa8f6ddd9bea05676d9c7d999308510f1f7d
# 4     0000000000000000000bf192140431a034e0ee713a13355bc36d0ec516f16094
#                                     ...
# 95    00000000000000000008b5cb4d434daa1a70ad860f6be4dda5a8cb8cfad251ef
# 96    00000000000000000009a292a55455fe8b857cc8d9dc049bf0f30f42c6610054
# 97    00000000000000000004155c8aef586faaa24a7a76498fefe2637218b40e1c2c
# 98    00000000000000000008f6309600345615a2f769892ae96b459e816ff235a0dd
# 99    0000000000000000000b6b6cbc221f9553aabdc641ca2f8fbe07968386bf6c6b
# Name: blockhash, Length: 100, dtype: object

# %%
blockchain
# Out:
#    avgfee avgfeerate avgtxsize  \
# 0    4196          5       907
# 1    6583         15       601
# 2    1337          3       511
# 3    4640         12       518
# 4    5140         18       400
# ..    ...        ...       ...
# 95   6559         14       787
# 96  18129         42       670
# 97   4760         15       473
# 98   3439          9       531
# 99   6623         15       689
#
#                                                            blockhash  height  \
# 0   00000000000000000009a8a019a7e05cf9dd888543f8e1a5449dea200c3922f5  703600
# 1   00000000000000000001dab19d08bf7a5a7dc350855eade998b75d6b74acff05  703601
# 2   000000000000000000095b45b8b7acc4e928d7ee0a413fecede707b145d0238b  703602
# 3   000000000000000000077ac614d0fa8f6ddd9bea05676d9c7d999308510f1f7d  703603
# 4   0000000000000000000bf192140431a034e0ee713a13355bc36d0ec516f16094  703604
# ..                                                               ...     ...
# 95  00000000000000000008b5cb4d434daa1a70ad860f6be4dda5a8cb8cfad251ef  703695
# 96  00000000000000000009a292a55455fe8b857cc8d9dc049bf0f30f42c6610054  703696
# 97  00000000000000000004155c8aef586faaa24a7a76498fefe2637218b40e1c2c  703697
# 98  00000000000000000008f6309600345615a2f769892ae96b459e816ff235a0dd  703698
# 99  0000000000000000000b6b6cbc221f9553aabdc641ca2f8fbe07968386bf6c6b  703699
#
#      ins   maxfee maxfeerate maxtxsize medianfee  ... swtotal_weight swtxs  \
# 0    917   236385        211     46682       722  ...         146115   158
# 1   6180  2546496        390    102640      1134  ...        2598714  1760
# 2   4026   100000        597     29747       327  ...        1462988  1459
# 3   5778  2546496        371    102579       800  ...        2674590  2063
# 4    537   371800        260     10538       864  ...         259522   247
# ..   ...      ...        ...       ...       ...  ...            ...   ...
# 95  6917  1051336        450    214400      1540  ...        3413712  1802
# 96  7338  8793012        484    170846      2602  ...        3183850  1781
# 97  7562   836600        302    102800      1421  ...        3182974  2733
# 98  6430   506188        348     34928      1130  ...        3161617  2270
# 99  7251   544240        506    102558      1360  ...        3012846  1764
#
#           time       total_out total_size total_weight  totalfee   txs  \
# 0   1633398665     52374292370     178693       632719    826721   198
# 1   1633400115   3791679762926    1401057      3996246  15333187  2330
# 2   1633400239   2560378823140     837850      2500480   2191189  1639
# 3   1633401249   3743004487423    1302513      3627402  11665765  2515
# 4   1633401367    107575540780     126069       353598   1619141   316
# ..         ...             ...        ...          ...       ...   ...
# 95  1633449556  10679600644339    1749336      3996564  14561125  2221
# 96  1633451019   5389401980494    1553895      3991578  41987952  2317
# 97  1633451594   7782147872874    1538989      3991774  15462610  3249
# 98  1633451936    991187484062    1501201      3991813   9712809  2825
# 99  1633452664   5980493496881    1568494      3997642  15061361  2275
#
#    utxo_increase utxo_size_inc
# 0            128         10130
# 1           3183        235899
# 2            469         63565
# 3           1990        166873
# 4            352         29726
# ..           ...           ...
# 95           136          6879
# 96           232         18345
# 97           797         62279
# 98          3029        228547
# 99           162         14841
#
# [100 rows x 28 columns]

# %%
blockchain.to_csv("clean_block_data.csv")
