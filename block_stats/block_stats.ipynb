# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
import numpy as np

# %%
blockchain = pd.read_csv("blockchain_data.csv")

# %%
blockchain
# Out:
#                        avgfee                 avgfeerate  \
# 0    ['  "avgfee": 10038,\n']  ['  "avgfeerate": 16,\n']
# 1     ['  "avgfee": 8144,\n']  ['  "avgfeerate": 18,\n']
# 2     ['  "avgfee": 2899,\n']   ['  "avgfeerate": 7,\n']
# 3     ['  "avgfee": 5627,\n']  ['  "avgfeerate": 17,\n']
# 4     ['  "avgfee": 6457,\n']  ['  "avgfeerate": 19,\n']
# ..                        ...                        ...
# 995   ['  "avgfee": 3443,\n']   ['  "avgfeerate": 9,\n']
# 996   ['  "avgfee": 3380,\n']  ['  "avgfeerate": 10,\n']
# 997   ['  "avgfee": 1925,\n']   ['  "avgfeerate": 3,\n']
# 998   ['  "avgfee": 5751,\n']  ['  "avgfeerate": 18,\n']
# 999   ['  "avgfee": 2244,\n']   ['  "avgfeerate": 6,\n']
#
#                      avgtxsize  \
# 0    ['  "avgtxsize": 744,\n']
# 1    ['  "avgtxsize": 616,\n']
# 2    ['  "avgtxsize": 684,\n']
# 3    ['  "avgtxsize": 473,\n']
# 4    ['  "avgtxsize": 483,\n']
# ..                         ...
# 995  ['  "avgtxsize": 574,\n']
# ...

# %%
blockchain["avgfee"] = blockchain["avgfee"].str.extract('(\d+)', expand=False)
blockchain["avgfeerate"] = blockchain["avgfeerate"].str.extract('(\d+)', expand=False)
blockchain["avgtxsize"] = blockchain["avgtxsize"].str.extract('(\d+)', expand=False)
blockchain["height"] = blockchain["height"].str.extract('(\d+)', expand=False)
blockchain["ins"] = blockchain["ins"].str.extract('(\d+)', expand=False)
blockchain["maxfee"] = blockchain["maxfee"].str.extract('(\d+)', expand=False)
blockchain["maxfeerate"] = blockchain["maxfeerate"].str.extract('(\d+)', expand=False)
blockchain["maxtxsize"] = blockchain["maxtxsize"].str.extract('(\d+)', expand=False)
blockchain["medianfee"] = blockchain["medianfee"].str.extract('(\d+)', expand=False)
blockchain["mediantime"] = blockchain["mediantime"].str.extract('(\d+)', expand=False)
blockchain["mediantxsize"] = blockchain["mediantxsize"].str.extract('(\d+)', expand=False)
blockchain["minfee"] = blockchain["minfee"].str.extract('(\d+)', expand=False)
blockchain["minfeerate"] = blockchain["minfeerate"].str.extract('(\d+)', expand=False)
blockchain["mintxsize"] = blockchain["mintxsize"].str.extract('(\d+)', expand=False)
blockchain["outs"] = blockchain["outs"].str.extract('(\d+)', expand=False)
blockchain["subsidy"] = blockchain["subsidy"].str.extract('(\d+)', expand=False)
blockchain["swtotal_size"] = blockchain["swtotal_size"].str.extract('(\d+)', expand=False)
blockchain["swtotal_weight"] = blockchain["swtotal_weight"].str.extract('(\d+)', expand=False)
blockchain["swtxs"] = blockchain["swtxs"].str.extract('(\d+)', expand=False)
blockchain["time"] = blockchain["time"].str.extract('(\d+)', expand=False)
blockchain["total_out"] = blockchain["total_out"].str.extract('(\d+)', expand=False)
blockchain["total_size"] = blockchain["total_size"].str.extract('(\d+)', expand=False)
blockchain["total_weight"] = blockchain["total_weight"].str.extract('(\d+)', expand=False)
blockchain["totalfee"] = blockchain["totalfee"].str.extract('(\d+)', expand=False)
blockchain["txs"] = blockchain["txs"].str.extract('(\d+)', expand=False)
blockchain["utxo_increase"] = blockchain["utxo_increase"].str.extract('([+-]?\d+)', expand=False)
blockchain["utxo_size_inc"] = blockchain["utxo_size_inc"].str.extract('(\d+)', expand=False)

# %%
print(blockchain['blockhash'])
# Out:
# 0      ['  "blockhash": "0000000000000000000384f28cb3b9cf4377a39cfd6c29ae9466951de38c0529",\n']
# 1      ['  "blockhash": "0000000000000000000528c4f2ac33f60261735fe26015f2fc6106813ea96489",\n']
# 2      ['  "blockhash": "000000000000000000018caa1a3306481eb53c246606e8d0857534797b43e9ab",\n']
# 3      ['  "blockhash": "00000000000000000006b1c48e5c5148998bfd47544c555c60c5587d0326a585",\n']
# 4      ['  "blockhash": "00000000000000000007f7a5b8e77b1c48b49245d248ee185d04cda9acf6771b",\n']
#                                                  ...
# 995    ['  "blockhash": "000000000000000000042e817c0dba737c02c2589a4887fc34b9da62d7444d77",\n']
# 996    ['  "blockhash": "0000000000000000000224164439e4eb190372edb10b1d9f0cdfdc0f6a2345a9",\n']
# 997    ['  "blockhash": "00000000000000000007b55b19514288505b339fd3c73d8b81c893cfda01449b",\n']
# 998    ['  "blockhash": "0000000000000000000120b0ee2ef019e5244f0c73e1725a063aa2e9b403f407",\n']
# ...

# %%
blockchain["blockhash"] = blockchain["blockhash"].str[18:82]

# %%
print(blockchain['blockhash'])
# Out:
# 0      0000000000000000000384f28cb3b9cf4377a39cfd6c29ae9466951de38c0529
# 1      0000000000000000000528c4f2ac33f60261735fe26015f2fc6106813ea96489
# 2      000000000000000000018caa1a3306481eb53c246606e8d0857534797b43e9ab
# 3      00000000000000000006b1c48e5c5148998bfd47544c555c60c5587d0326a585
# 4      00000000000000000007f7a5b8e77b1c48b49245d248ee185d04cda9acf6771b
#                                      ...
# 995    000000000000000000042e817c0dba737c02c2589a4887fc34b9da62d7444d77
# 996    0000000000000000000224164439e4eb190372edb10b1d9f0cdfdc0f6a2345a9
# 997    00000000000000000007b55b19514288505b339fd3c73d8b81c893cfda01449b
# 998    0000000000000000000120b0ee2ef019e5244f0c73e1725a063aa2e9b403f407
# 999    00000000000000000003e3d7a90346930f0140c37abc7bbcc7c4c62dfbce4d86
# Name: blockhash, Length: 1000, dtype: object

# %%
blockchain
# Out:
#     avgfee avgfeerate avgtxsize  \
# 0    10038         16       744
# 1     8144         18       616
# 2     2899          7       684
# 3     5627         17       473
# 4     6457         19       483
# ..     ...        ...       ...
# 995   3443          9       574
# 996   3380         10       494
# 997   1925          3       842
# 998   5751         18       467
# 999   2244          6       491
#
#                                                             blockhash  height  \
# 0    0000000000000000000384f28cb3b9cf4377a39cfd6c29ae9466951de38c0529  730000
# 1    0000000000000000000528c4f2ac33f60261735fe26015f2fc6106813ea96489  730001
# 2    000000000000000000018caa1a3306481eb53c246606e8d0857534797b43e9ab  730002
# 3    00000000000000000006b1c48e5c5148998bfd47544c555c60c5587d0326a585  730003
# 4    00000000000000000007f7a5b8e77b1c48b49245d248ee185d04cda9acf6771b  730004
# ..                                                                ...     ...
# ...

# %%
blockchain.to_csv("clean_block_data.csv")

# %%
blockchain.to_csv("~/PycharmProjects/bitcoin_dash/clean_block_data.csv")
