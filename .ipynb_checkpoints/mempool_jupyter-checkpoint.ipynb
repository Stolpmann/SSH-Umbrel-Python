# %%
import pandas as pd
import numpy as np

# %%
blockchain = pd.read_csv("blockchain_data.csv")

# %%
blockchain
# Out:
#                      avgfee                 avgfeerate  \
# 0  ['  "avgfee": 12069,\n']  ['  "avgfeerate": 15,\n']
# 1   ['  "avgfee": 2078,\n']   ['  "avgfeerate": 2,\n']
# 2   ['  "avgfee": 4082,\n']   ['  "avgfeerate": 8,\n']
# 3  ['  "avgfee": 25372,\n']  ['  "avgfeerate": 35,\n']
# 4   ['  "avgfee": 5484,\n']  ['  "avgfeerate": 11,\n']
# 5   ['  "avgfee": 4076,\n']  ['  "avgfeerate": 10,\n']
# 6   ['  "avgfee": 7852,\n']  ['  "avgfeerate": 15,\n']
# 7   ['  "avgfee": 8023,\n']  ['  "avgfeerate": 16,\n']
# 8   ['  "avgfee": 6225,\n']  ['  "avgfeerate": 15,\n']
# 9   ['  "avgfee": 3048,\n']   ['  "avgfeerate": 5,\n']
#
#                     avgtxsize  \
# 0  ['  "avgtxsize": 1000,\n']
# 1   ['  "avgtxsize": 956,\n']
# 2   ['  "avgtxsize": 627,\n']
# 3   ['  "avgtxsize": 981,\n']
# 4   ['  "avgtxsize": 831,\n']
# 5   ['  "avgtxsize": 552,\n']
# 6   ['  "avgtxsize": 680,\n']
# 7   ['  "avgtxsize": 723,\n']
# 8   ['  "avgtxsize": 562,\n']
# 9   ['  "avgtxsize": 703,\n']
#
#                                            blockhash  \
# 0  ['  "blockhash": "0000000000000000000590fc0f3e...
# 1  ['  "blockhash": "00000000000000000002f39baabb...
# 2  ['  "blockhash": "00000000000000000001993b6b5e...
# 3  ['  "blockhash": "000000000000000000055646f272...
# 4  ['  "blockhash": "0000000000000000000e360e05cb...
# 5  ['  "blockhash": "0000000000000000000add9a48ae...
# 6  ['  "blockhash": "00000000000000000005975f6e83...
# 7  ['  "blockhash": "0000000000000000000a5f9662af...
# 8  ['  "blockhash": "0000000000000000000bd59e4233...
# 9  ['  "blockhash": "0000000000000000000190997c46...
#
#                       height                   ins  \
# 0  ['  "height": 700000,\n']  ['  "ins": 6342,\n']
# 1  ['  "height": 700001,\n']  ['  "ins": 2435,\n']
# 2  ['  "height": 700002,\n']   ['  "ins": 729,\n']
# 3  ['  "height": 700003,\n']   ['  "ins": 716,\n']
# 4  ['  "height": 700004,\n']  ['  "ins": 1174,\n']
# 5  ['  "height": 700005,\n']  ['  "ins": 1924,\n']
# 6  ['  "height": 700006,\n']   ['  "ins": 618,\n']
# 7  ['  "height": 700007,\n']  ['  "ins": 4141,\n']
# 8  ['  "height": 700008,\n']  ['  "ins": 6130,\n']
# 9  ['  "height": 700009,\n']  ['  "ins": 2176,\n']
#
#                        maxfee                  maxfeerate  \
# 0  ['  "maxfee": 1400000,\n']  ['  "maxfeerate": 358,\n']
# 1   ['  "maxfee": 153000,\n']  ['  "maxfeerate": 251,\n']
# 2    ['  "maxfee": 59549,\n']  ['  "maxfeerate": 316,\n']
# 3  ['  "maxfee": 2546496,\n']  ['  "maxfeerate": 202,\n']
# 4   ['  "maxfee": 283320,\n']  ['  "maxfeerate": 477,\n']
# 5   ['  "maxfee": 140826,\n']  ['  "maxfeerate": 160,\n']
# 6   ['  "maxfee": 173400,\n']  ['  "maxfeerate": 192,\n']
# 7   ['  "maxfee": 584712,\n']  ['  "maxfeerate": 389,\n']
# 8   ['  "maxfee": 388224,\n']  ['  "maxfeerate": 605,\n']
# 9   ['  "maxfee": 164097,\n']  ['  "maxfeerate": 155,\n']
#
#                      maxtxsize                   medianfee  ...  \
# 0  ['  "maxtxsize": 86228,\n']  ['  "medianfee": 1512,\n']  ...
# 1  ['  "maxtxsize": 46044,\n']   ['  "medianfee": 336,\n']  ...
# 2  ['  "maxtxsize": 22613,\n']  ['  "medianfee": 1363,\n']  ...
# 3  ['  "maxtxsize": 35443,\n']  ['  "medianfee": 1486,\n']  ...
# 4  ['  "maxtxsize": 53046,\n']  ['  "medianfee": 1323,\n']  ...
# 5  ['  "maxtxsize": 23237,\n']  ['  "medianfee": 1101,\n']  ...
# 6  ['  "maxtxsize": 22173,\n']  ['  "medianfee": 1275,\n']  ...
# 7  ['  "maxtxsize": 72988,\n']  ['  "medianfee": 1333,\n']  ...
# 8  ['  "maxtxsize": 61070,\n']  ['  "medianfee": 1396,\n']  ...
# 9  ['  "maxtxsize": 46079,\n']   ['  "medianfee": 452,\n']  ...
#
#                        swtotal_weight                   swtxs  \
# 0  ['  "swtotal_weight": 2749806,\n']   ['  "swtxs": 939,\n']
# 1   ['  "swtotal_weight": 679348,\n']   ['  "swtxs": 423,\n']
# 2   ['  "swtotal_weight": 240300,\n']   ['  "swtxs": 186,\n']
# 3   ['  "swtotal_weight": 181253,\n']    ['  "swtxs": 90,\n']
# 4   ['  "swtotal_weight": 532137,\n']   ['  "swtxs": 254,\n']
# 5   ['  "swtotal_weight": 783009,\n']   ['  "swtxs": 561,\n']
# 6   ['  "swtotal_weight": 238306,\n']   ['  "swtxs": 147,\n']
# 7  ['  "swtotal_weight": 1778025,\n']   ['  "swtxs": 985,\n']
# 8  ['  "swtotal_weight": 2493668,\n']  ['  "swtxs": 1850,\n']
# 9   ['  "swtotal_weight": 962582,\n']   ['  "swtxs": 575,\n']
#
#                           time                            total_out  \
# 0  ['  "time": 1631333672,\n']  ['  "total_out": 4960138797209,\n']
# 1  ['  "time": 1631333702,\n']    ['  "total_out": 21643550568,\n']
# 2  ['  "time": 1631333827,\n']  ['  "total_out": 2291721978694,\n']
# 3  ['  "time": 1631333877,\n']  ['  "total_out": 2264155720920,\n']
# 4  ['  "time": 1631334045,\n']    ['  "total_out": 42637502244,\n']
# 5  ['  "time": 1631334474,\n']    ['  "total_out": 79354950672,\n']
# 6  ['  "time": 1631334600,\n']  ['  "total_out": 2292983899306,\n']
# 7  ['  "time": 1631335351,\n']  ['  "total_out": 7100723072452,\n']
# 8  ['  "time": 1631337023,\n']  ['  "total_out": 5062345759872,\n']
# 9  ['  "time": 1631337205,\n']   ['  "total_out": 133409776125,\n']
#
#                        total_size                      total_weight  \
# 0  ['  "total_size": 1276027,\n']  ['  "total_weight": 3996622,\n']
# 1   ['  "total_size": 473624,\n']  ['  "total_weight": 1433396,\n']
# 2   ['  "total_size": 159487,\n']   ['  "total_weight": 461632,\n']
# 3   ['  "total_size": 128543,\n']   ['  "total_weight": 373541,\n']
# 4   ['  "total_size": 265366,\n']   ['  "total_weight": 619369,\n']
# 5   ['  "total_size": 407791,\n']  ['  "total_weight": 1140049,\n']
# 6   ['  "total_size": 140867,\n']   ['  "total_weight": 412274,\n']
# 7   ['  "total_size": 969331,\n']  ['  "total_weight": 2630377,\n']
# 8  ['  "total_size": 1384758,\n']  ['  "total_weight": 3997992,\n']
# 9   ['  "total_size": 496257,\n']  ['  "total_weight": 1446510,\n']
#
#                         totalfee                   txs  \
# 0  ['  "totalfee": 15388640,\n']  ['  "txs": 1276,\n']
# 1   ['  "totalfee": 1028918,\n']   ['  "txs": 496,\n']
# 2   ['  "totalfee": 1036999,\n']   ['  "txs": 255,\n']
# 3   ['  "totalfee": 3323862,\n']   ['  "txs": 132,\n']
# 4   ['  "totalfee": 1749708,\n']   ['  "txs": 320,\n']
# 5   ['  "totalfee": 3008389,\n']   ['  "txs": 739,\n']
# 6   ['  "totalfee": 1625392,\n']   ['  "txs": 208,\n']
# 7  ['  "totalfee": 10752114,\n']  ['  "txs": 1341,\n']
# 8  ['  "totalfee": 15333181,\n']  ['  "txs": 2464,\n']
# 9   ['  "totalfee": 2149090,\n']   ['  "txs": 706,\n']
#
#                     utxo_increase                    utxo_size_inc
# 0  ['  "utxo_increase": -186,\n']  ['  "utxo_size_inc": -15021\n']
# 1  ['  "utxo_increase": -738,\n']  ['  "utxo_size_inc": -47985\n']
# 2   ['  "utxo_increase": -75,\n']   ['  "utxo_size_inc": -3969\n']
# 3  ['  "utxo_increase": -330,\n']  ['  "utxo_size_inc": -23618\n']
# 4  ['  "utxo_increase": -129,\n']   ['  "utxo_size_inc": -7715\n']
# 5   ['  "utxo_increase": 413,\n']   ['  "utxo_size_inc": 35140\n']
# 6   ['  "utxo_increase": 378,\n']   ['  "utxo_size_inc": 28800\n']
# 7  ['  "utxo_increase": 2048,\n']  ['  "utxo_size_inc": 156780\n']
# 8  ['  "utxo_increase": 3689,\n']  ['  "utxo_size_inc": 271862\n']
# 9   ['  "utxo_increase": 676,\n']   ['  "utxo_size_inc": 61442\n']
#
# [10 rows x 28 columns]

# %%
blockchain['avgfee', 'avgfeerate', "avgtxsize", "blockhash",
                         "height", "ins", "maxfee", "maxfeerate", "maxtxsize",
                         "medianfee", "mediantime", "mediantxsize", "minfee",
                         "minfeerate", "mintxsize", "outs", "subsidy", "swtotal_size",
                         "swtotal_weight", "swtxs", "time", "total_out", "total_size",
                         "total_weight", "totalfee", "txs", "utxo_increase", "utxo_size_inc"] = blockchain['avgfee', 'avgfeerate', "avgtxsize", "blockhash",
                         "height", "ins", "maxfee", "maxfeerate", "maxtxsize",
                         "medianfee", "mediantime", "mediantxsize", "minfee",
                         "minfeerate", "mintxsize", "outs", "subsidy", "swtotal_size",
                         "swtotal_weight", "swtxs", "time", "total_out", "total_size",
                         "total_weight", "totalfee", "txs", "utxo_increase", "utxo_size_inc"].str.extract('(\d+)', expand=False)
# Out:
#   File "<ipython-input-19-92531f02523c>", line 6
#     "total_weight", "totalfee", "txs", "utxo_increase", "utxo_size_inc"] =
#                                                                            ^
# SyntaxError: invalid syntax

# %%
blockchain
# Out:
#   avgfee                 avgfeerate                   avgtxsize  \
# 0  12069  ['  "avgfeerate": 15,\n']  ['  "avgtxsize": 1000,\n']
# 1   2078   ['  "avgfeerate": 2,\n']   ['  "avgtxsize": 956,\n']
# 2   4082   ['  "avgfeerate": 8,\n']   ['  "avgtxsize": 627,\n']
# 3  25372  ['  "avgfeerate": 35,\n']   ['  "avgtxsize": 981,\n']
# 4   5484  ['  "avgfeerate": 11,\n']   ['  "avgtxsize": 831,\n']
# 5   4076  ['  "avgfeerate": 10,\n']   ['  "avgtxsize": 552,\n']
# 6   7852  ['  "avgfeerate": 15,\n']   ['  "avgtxsize": 680,\n']
# 7   8023  ['  "avgfeerate": 16,\n']   ['  "avgtxsize": 723,\n']
# 8   6225  ['  "avgfeerate": 15,\n']   ['  "avgtxsize": 562,\n']
# 9   3048   ['  "avgfeerate": 5,\n']   ['  "avgtxsize": 703,\n']
#
#                                            blockhash  \
# 0  ['  "blockhash": "0000000000000000000590fc0f3e...
# 1  ['  "blockhash": "00000000000000000002f39baabb...
# 2  ['  "blockhash": "00000000000000000001993b6b5e...
# 3  ['  "blockhash": "000000000000000000055646f272...
# 4  ['  "blockhash": "0000000000000000000e360e05cb...
# 5  ['  "blockhash": "0000000000000000000add9a48ae...
# 6  ['  "blockhash": "00000000000000000005975f6e83...
# 7  ['  "blockhash": "0000000000000000000a5f9662af...
# 8  ['  "blockhash": "0000000000000000000bd59e4233...
# 9  ['  "blockhash": "0000000000000000000190997c46...
#
#                       height                   ins  \
# 0  ['  "height": 700000,\n']  ['  "ins": 6342,\n']
# 1  ['  "height": 700001,\n']  ['  "ins": 2435,\n']
# 2  ['  "height": 700002,\n']   ['  "ins": 729,\n']
# 3  ['  "height": 700003,\n']   ['  "ins": 716,\n']
# 4  ['  "height": 700004,\n']  ['  "ins": 1174,\n']
# 5  ['  "height": 700005,\n']  ['  "ins": 1924,\n']
# 6  ['  "height": 700006,\n']   ['  "ins": 618,\n']
# 7  ['  "height": 700007,\n']  ['  "ins": 4141,\n']
# 8  ['  "height": 700008,\n']  ['  "ins": 6130,\n']
# 9  ['  "height": 700009,\n']  ['  "ins": 2176,\n']
#
#                        maxfee                  maxfeerate  \
# 0  ['  "maxfee": 1400000,\n']  ['  "maxfeerate": 358,\n']
# 1   ['  "maxfee": 153000,\n']  ['  "maxfeerate": 251,\n']
# 2    ['  "maxfee": 59549,\n']  ['  "maxfeerate": 316,\n']
# 3  ['  "maxfee": 2546496,\n']  ['  "maxfeerate": 202,\n']
# 4   ['  "maxfee": 283320,\n']  ['  "maxfeerate": 477,\n']
# 5   ['  "maxfee": 140826,\n']  ['  "maxfeerate": 160,\n']
# 6   ['  "maxfee": 173400,\n']  ['  "maxfeerate": 192,\n']
# 7   ['  "maxfee": 584712,\n']  ['  "maxfeerate": 389,\n']
# 8   ['  "maxfee": 388224,\n']  ['  "maxfeerate": 605,\n']
# 9   ['  "maxfee": 164097,\n']  ['  "maxfeerate": 155,\n']
#
#                      maxtxsize                   medianfee  ...  \
# 0  ['  "maxtxsize": 86228,\n']  ['  "medianfee": 1512,\n']  ...
# 1  ['  "maxtxsize": 46044,\n']   ['  "medianfee": 336,\n']  ...
# 2  ['  "maxtxsize": 22613,\n']  ['  "medianfee": 1363,\n']  ...
# 3  ['  "maxtxsize": 35443,\n']  ['  "medianfee": 1486,\n']  ...
# 4  ['  "maxtxsize": 53046,\n']  ['  "medianfee": 1323,\n']  ...
# 5  ['  "maxtxsize": 23237,\n']  ['  "medianfee": 1101,\n']  ...
# 6  ['  "maxtxsize": 22173,\n']  ['  "medianfee": 1275,\n']  ...
# 7  ['  "maxtxsize": 72988,\n']  ['  "medianfee": 1333,\n']  ...
# 8  ['  "maxtxsize": 61070,\n']  ['  "medianfee": 1396,\n']  ...
# 9  ['  "maxtxsize": 46079,\n']   ['  "medianfee": 452,\n']  ...
#
#                        swtotal_weight                   swtxs  \
# 0  ['  "swtotal_weight": 2749806,\n']   ['  "swtxs": 939,\n']
# 1   ['  "swtotal_weight": 679348,\n']   ['  "swtxs": 423,\n']
# 2   ['  "swtotal_weight": 240300,\n']   ['  "swtxs": 186,\n']
# 3   ['  "swtotal_weight": 181253,\n']    ['  "swtxs": 90,\n']
# 4   ['  "swtotal_weight": 532137,\n']   ['  "swtxs": 254,\n']
# 5   ['  "swtotal_weight": 783009,\n']   ['  "swtxs": 561,\n']
# 6   ['  "swtotal_weight": 238306,\n']   ['  "swtxs": 147,\n']
# 7  ['  "swtotal_weight": 1778025,\n']   ['  "swtxs": 985,\n']
# 8  ['  "swtotal_weight": 2493668,\n']  ['  "swtxs": 1850,\n']
# 9   ['  "swtotal_weight": 962582,\n']   ['  "swtxs": 575,\n']
#
#                           time                            total_out  \
# 0  ['  "time": 1631333672,\n']  ['  "total_out": 4960138797209,\n']
# 1  ['  "time": 1631333702,\n']    ['  "total_out": 21643550568,\n']
# 2  ['  "time": 1631333827,\n']  ['  "total_out": 2291721978694,\n']
# 3  ['  "time": 1631333877,\n']  ['  "total_out": 2264155720920,\n']
# 4  ['  "time": 1631334045,\n']    ['  "total_out": 42637502244,\n']
# 5  ['  "time": 1631334474,\n']    ['  "total_out": 79354950672,\n']
# 6  ['  "time": 1631334600,\n']  ['  "total_out": 2292983899306,\n']
# 7  ['  "time": 1631335351,\n']  ['  "total_out": 7100723072452,\n']
# 8  ['  "time": 1631337023,\n']  ['  "total_out": 5062345759872,\n']
# 9  ['  "time": 1631337205,\n']   ['  "total_out": 133409776125,\n']
#
#                        total_size                      total_weight  \
# 0  ['  "total_size": 1276027,\n']  ['  "total_weight": 3996622,\n']
# 1   ['  "total_size": 473624,\n']  ['  "total_weight": 1433396,\n']
# 2   ['  "total_size": 159487,\n']   ['  "total_weight": 461632,\n']
# 3   ['  "total_size": 128543,\n']   ['  "total_weight": 373541,\n']
# 4   ['  "total_size": 265366,\n']   ['  "total_weight": 619369,\n']
# 5   ['  "total_size": 407791,\n']  ['  "total_weight": 1140049,\n']
# 6   ['  "total_size": 140867,\n']   ['  "total_weight": 412274,\n']
# 7   ['  "total_size": 969331,\n']  ['  "total_weight": 2630377,\n']
# 8  ['  "total_size": 1384758,\n']  ['  "total_weight": 3997992,\n']
# 9   ['  "total_size": 496257,\n']  ['  "total_weight": 1446510,\n']
#
#                         totalfee                   txs  \
# 0  ['  "totalfee": 15388640,\n']  ['  "txs": 1276,\n']
# 1   ['  "totalfee": 1028918,\n']   ['  "txs": 496,\n']
# 2   ['  "totalfee": 1036999,\n']   ['  "txs": 255,\n']
# 3   ['  "totalfee": 3323862,\n']   ['  "txs": 132,\n']
# 4   ['  "totalfee": 1749708,\n']   ['  "txs": 320,\n']
# 5   ['  "totalfee": 3008389,\n']   ['  "txs": 739,\n']
# 6   ['  "totalfee": 1625392,\n']   ['  "txs": 208,\n']
# 7  ['  "totalfee": 10752114,\n']  ['  "txs": 1341,\n']
# 8  ['  "totalfee": 15333181,\n']  ['  "txs": 2464,\n']
# 9   ['  "totalfee": 2149090,\n']   ['  "txs": 706,\n']
#
#                     utxo_increase                    utxo_size_inc
# 0  ['  "utxo_increase": -186,\n']  ['  "utxo_size_inc": -15021\n']
# 1  ['  "utxo_increase": -738,\n']  ['  "utxo_size_inc": -47985\n']
# 2   ['  "utxo_increase": -75,\n']   ['  "utxo_size_inc": -3969\n']
# 3  ['  "utxo_increase": -330,\n']  ['  "utxo_size_inc": -23618\n']
# 4  ['  "utxo_increase": -129,\n']   ['  "utxo_size_inc": -7715\n']
# 5   ['  "utxo_increase": 413,\n']   ['  "utxo_size_inc": 35140\n']
# 6   ['  "utxo_increase": 378,\n']   ['  "utxo_size_inc": 28800\n']
# 7  ['  "utxo_increase": 2048,\n']  ['  "utxo_size_inc": 156780\n']
# 8  ['  "utxo_increase": 3689,\n']  ['  "utxo_size_inc": 271862\n']
# 9   ['  "utxo_increase": 676,\n']   ['  "utxo_size_inc": 61442\n']
#
# [10 rows x 28 columns]
