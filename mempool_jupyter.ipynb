# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
import numpy as np

# %%
blockchain = pd.read_csv("blockchain_data.csv")

# %%
blockchain
# Out:
#                      avgfee                 avgfeerate  \
# 0  ['  "avgfee": 12069,\n']  ['  "avgfeerate": 15,\n']
# 1   ['  "avgfee": 2078,\n']   ['  "avgfeerate": 2,\n']
# 2   ['  "avgfee": 4082,\n']   ['  "avgfeerate": 8,\n']
# 3  ['  "avgfee": 25372,\n']  ['  "avgfeerate": 35,\n']
# 4   ['  "avgfee": 5484,\n']  ['  "avgfeerate": 11,\n']
# 5   ['  "avgfee": 4076,\n']  ['  "avgfeerate": 10,\n']
# 6   ['  "avgfee": 7852,\n']  ['  "avgfeerate": 15,\n']
# 7   ['  "avgfee": 8023,\n']  ['  "avgfeerate": 16,\n']
# 8   ['  "avgfee": 6225,\n']  ['  "avgfeerate": 15,\n']
# 9   ['  "avgfee": 3048,\n']   ['  "avgfeerate": 5,\n']
#
#                     avgtxsize  \
# 0  ['  "avgtxsize": 1000,\n']
# 1   ['  "avgtxsize": 956,\n']
# 2   ['  "avgtxsize": 627,\n']
# 3   ['  "avgtxsize": 981,\n']
# 4   ['  "avgtxsize": 831,\n']
# 5   ['  "avgtxsize": 552,\n']
# 6   ['  "avgtxsize": 680,\n']
# 7   ['  "avgtxsize": 723,\n']
# 8   ['  "avgtxsize": 562,\n']
# 9   ['  "avgtxsize": 703,\n']
#
#                                                                                   blockhash  \
# 0  ['  "blockhash": "0000000000000000000590fc0f3eba193a278534220b2b37e9849e1a770ca959",\n']
# 1  ['  "blockhash": "00000000000000000002f39baabb00ffeb47dbdb425d5077baa62c47482b7e92",\n']
# 2  ['  "blockhash": "00000000000000000001993b6b5e4e3dac1187820bccc5ab324d6f01c05d6146",\n']
# 3  ['  "blockhash": "000000000000000000055646f272b32b2b844137f215163229aed0099f2a6640",\n']
# 4  ['  "blockhash": "0000000000000000000e360e05cb9d7b238b95cc881726d0519e0449be361d9e",\n']
# 5  ['  "blockhash": "0000000000000000000add9a48ae518c8e1aab061d313cf8c07a69e860c7ec0b",\n']
# 6  ['  "blockhash": "00000000000000000005975f6e8351d800c47eb3ec41b30586b001f382f5e47d",\n']
# 7  ['  "blockhash": "0000000000000000000a5f9662af95174b8ff46df4b7cbae4334283a1465dcb0",\n']
# 8  ['  "blockhash": "0000000000000000000bd59e42336960925a4c465459b6208eebcb22ecfe0839",\n']
# 9  ['  "blockhash": "0000000000000000000190997c460412aab3ed2a260447c896f16f8a3e17dd87",\n']
#
#                       height                   ins  \
# 0  ['  "height": 700000,\n']  ['  "ins": 6342,\n']
# 1  ['  "height": 700001,\n']  ['  "ins": 2435,\n']
# 2  ['  "height": 700002,\n']   ['  "ins": 729,\n']
# 3  ['  "height": 700003,\n']   ['  "ins": 716,\n']
# 4  ['  "height": 700004,\n']  ['  "ins": 1174,\n']
# 5  ['  "height": 700005,\n']  ['  "ins": 1924,\n']
# 6  ['  "height": 700006,\n']   ['  "ins": 618,\n']
# 7  ['  "height": 700007,\n']  ['  "ins": 4141,\n']
# 8  ['  "height": 700008,\n']  ['  "ins": 6130,\n']
# 9  ['  "height": 700009,\n']  ['  "ins": 2176,\n']
#
#                        maxfee                  maxfeerate  \
# 0  ['  "maxfee": 1400000,\n']  ['  "maxfeerate": 358,\n']
# 1   ['  "maxfee": 153000,\n']  ['  "maxfeerate": 251,\n']
# 2    ['  "maxfee": 59549,\n']  ['  "maxfeerate": 316,\n']
# 3  ['  "maxfee": 2546496,\n']  ['  "maxfeerate": 202,\n']
# 4   ['  "maxfee": 283320,\n']  ['  "maxfeerate": 477,\n']
# 5   ['  "maxfee": 140826,\n']  ['  "maxfeerate": 160,\n']
# 6   ['  "maxfee": 173400,\n']  ['  "maxfeerate": 192,\n']
# 7   ['  "maxfee": 584712,\n']  ['  "maxfeerate": 389,\n']
# 8   ['  "maxfee": 388224,\n']  ['  "maxfeerate": 605,\n']
# 9   ['  "maxfee": 164097,\n']  ['  "maxfeerate": 155,\n']
#
#                      maxtxsize                   medianfee  ...  \
# 0  ['  "maxtxsize": 86228,\n']  ['  "medianfee": 1512,\n']  ...
# 1  ['  "maxtxsize": 46044,\n']   ['  "medianfee": 336,\n']  ...
# 2  ['  "maxtxsize": 22613,\n']  ['  "medianfee": 1363,\n']  ...
# 3  ['  "maxtxsize": 35443,\n']  ['  "medianfee": 1486,\n']  ...
# 4  ['  "maxtxsize": 53046,\n']  ['  "medianfee": 1323,\n']  ...
# 5  ['  "maxtxsize": 23237,\n']  ['  "medianfee": 1101,\n']  ...
# 6  ['  "maxtxsize": 22173,\n']  ['  "medianfee": 1275,\n']  ...
# 7  ['  "maxtxsize": 72988,\n']  ['  "medianfee": 1333,\n']  ...
# 8  ['  "maxtxsize": 61070,\n']  ['  "medianfee": 1396,\n']  ...
# 9  ['  "maxtxsize": 46079,\n']   ['  "medianfee": 452,\n']  ...
#
#                        swtotal_weight                   swtxs  \
# 0  ['  "swtotal_weight": 2749806,\n']   ['  "swtxs": 939,\n']
# 1   ['  "swtotal_weight": 679348,\n']   ['  "swtxs": 423,\n']
# 2   ['  "swtotal_weight": 240300,\n']   ['  "swtxs": 186,\n']
# 3   ['  "swtotal_weight": 181253,\n']    ['  "swtxs": 90,\n']
# 4   ['  "swtotal_weight": 532137,\n']   ['  "swtxs": 254,\n']
# 5   ['  "swtotal_weight": 783009,\n']   ['  "swtxs": 561,\n']
# 6   ['  "swtotal_weight": 238306,\n']   ['  "swtxs": 147,\n']
# 7  ['  "swtotal_weight": 1778025,\n']   ['  "swtxs": 985,\n']
# 8  ['  "swtotal_weight": 2493668,\n']  ['  "swtxs": 1850,\n']
# 9   ['  "swtotal_weight": 962582,\n']   ['  "swtxs": 575,\n']
#
#                           time                            total_out  \
# 0  ['  "time": 1631333672,\n']  ['  "total_out": 4960138797209,\n']
# 1  ['  "time": 1631333702,\n']    ['  "total_out": 21643550568,\n']
# 2  ['  "time": 1631333827,\n']  ['  "total_out": 2291721978694,\n']
# 3  ['  "time": 1631333877,\n']  ['  "total_out": 2264155720920,\n']
# 4  ['  "time": 1631334045,\n']    ['  "total_out": 42637502244,\n']
# 5  ['  "time": 1631334474,\n']    ['  "total_out": 79354950672,\n']
# 6  ['  "time": 1631334600,\n']  ['  "total_out": 2292983899306,\n']
# 7  ['  "time": 1631335351,\n']  ['  "total_out": 7100723072452,\n']
# 8  ['  "time": 1631337023,\n']  ['  "total_out": 5062345759872,\n']
# 9  ['  "time": 1631337205,\n']   ['  "total_out": 133409776125,\n']
#
#                        total_size                      total_weight  \
# 0  ['  "total_size": 1276027,\n']  ['  "total_weight": 3996622,\n']
# 1   ['  "total_size": 473624,\n']  ['  "total_weight": 1433396,\n']
# 2   ['  "total_size": 159487,\n']   ['  "total_weight": 461632,\n']
# 3   ['  "total_size": 128543,\n']   ['  "total_weight": 373541,\n']
# 4   ['  "total_size": 265366,\n']   ['  "total_weight": 619369,\n']
# 5   ['  "total_size": 407791,\n']  ['  "total_weight": 1140049,\n']
# 6   ['  "total_size": 140867,\n']   ['  "total_weight": 412274,\n']
# 7   ['  "total_size": 969331,\n']  ['  "total_weight": 2630377,\n']
# 8  ['  "total_size": 1384758,\n']  ['  "total_weight": 3997992,\n']
# 9   ['  "total_size": 496257,\n']  ['  "total_weight": 1446510,\n']
#
#                         totalfee                   txs  \
# 0  ['  "totalfee": 15388640,\n']  ['  "txs": 1276,\n']
# 1   ['  "totalfee": 1028918,\n']   ['  "txs": 496,\n']
# 2   ['  "totalfee": 1036999,\n']   ['  "txs": 255,\n']
# 3   ['  "totalfee": 3323862,\n']   ['  "txs": 132,\n']
# 4   ['  "totalfee": 1749708,\n']   ['  "txs": 320,\n']
# 5   ['  "totalfee": 3008389,\n']   ['  "txs": 739,\n']
# 6   ['  "totalfee": 1625392,\n']   ['  "txs": 208,\n']
# 7  ['  "totalfee": 10752114,\n']  ['  "txs": 1341,\n']
# 8  ['  "totalfee": 15333181,\n']  ['  "txs": 2464,\n']
# 9   ['  "totalfee": 2149090,\n']   ['  "txs": 706,\n']
#
#                     utxo_increase                    utxo_size_inc
# 0  ['  "utxo_increase": -186,\n']  ['  "utxo_size_inc": -15021\n']
# 1  ['  "utxo_increase": -738,\n']  ['  "utxo_size_inc": -47985\n']
# 2   ['  "utxo_increase": -75,\n']   ['  "utxo_size_inc": -3969\n']
# 3  ['  "utxo_increase": -330,\n']  ['  "utxo_size_inc": -23618\n']
# 4  ['  "utxo_increase": -129,\n']   ['  "utxo_size_inc": -7715\n']
# 5   ['  "utxo_increase": 413,\n']   ['  "utxo_size_inc": 35140\n']
# 6   ['  "utxo_increase": 378,\n']   ['  "utxo_size_inc": 28800\n']
# 7  ['  "utxo_increase": 2048,\n']  ['  "utxo_size_inc": 156780\n']
# 8  ['  "utxo_increase": 3689,\n']  ['  "utxo_size_inc": 271862\n']
# 9   ['  "utxo_increase": 676,\n']   ['  "utxo_size_inc": 61442\n']
#
# [10 rows x 28 columns]

# %%
blockchain["avgfee"] = blockchain["avgfee"].str.extract('(\d+)', expand=False)
blockchain["avgfeerate"] = blockchain["avgfeerate"].str.extract('(\d+)', expand=False)
blockchain["avgtxsize"] = blockchain["avgtxsize"].str.extract('(\d+)', expand=False)
blockchain["height"] = blockchain["height"].str.extract('(\d+)', expand=False)
blockchain["ins"] = blockchain["ins"].str.extract('(\d+)', expand=False)
blockchain["maxfee"] = blockchain["maxfee"].str.extract('(\d+)', expand=False)
blockchain["maxfeerate"] = blockchain["maxfeerate"].str.extract('(\d+)', expand=False)
blockchain["maxtxsize"] = blockchain["maxtxsize"].str.extract('(\d+)', expand=False)
blockchain["medianfee"] = blockchain["medianfee"].str.extract('(\d+)', expand=False)
blockchain["mediantime"] = blockchain["mediantime"].str.extract('(\d+)', expand=False)
blockchain["mediantxsize"] = blockchain["mediantxsize"].str.extract('(\d+)', expand=False)
blockchain["minfee"] = blockchain["minfee"].str.extract('(\d+)', expand=False)
blockchain["minfeerate"] = blockchain["minfeerate"].str.extract('(\d+)', expand=False)
blockchain["mintxsize"] = blockchain["mintxsize"].str.extract('(\d+)', expand=False)
blockchain["outs"] = blockchain["outs"].str.extract('(\d+)', expand=False)
blockchain["subsidy"] = blockchain["subsidy"].str.extract('(\d+)', expand=False)
blockchain["swtotal_size"] = blockchain["swtotal_size"].str.extract('(\d+)', expand=False)
blockchain["swtotal_weight"] = blockchain["swtotal_weight"].str.extract('(\d+)', expand=False)
blockchain["swtxs"] = blockchain["swtxs"].str.extract('(\d+)', expand=False)
blockchain["time"] = blockchain["time"].str.extract('(\d+)', expand=False)
blockchain["total_out"] = blockchain["total_out"].str.extract('(\d+)', expand=False)
blockchain["total_size"] = blockchain["total_size"].str.extract('(\d+)', expand=False)
blockchain["total_weight"] = blockchain["total_weight"].str.extract('(\d+)', expand=False)
blockchain["totalfee"] = blockchain["totalfee"].str.extract('(\d+)', expand=False)
blockchain["txs"] = blockchain["txs"].str.extract('(\d+)', expand=False)
blockchain["utxo_increase"] = blockchain["utxo_increase"].str.extract('(\d+)', expand=False)
blockchain["utxo_size_inc"] = blockchain["utxo_size_inc"].str.extract('(\d+)', expand=False)

# %%
print(blockchain['blockhash'])
# Out:
# 0    ['  "blockhash": "0000000000000000000590fc0f3eba193a278534220b2b37e9849e1a770ca959",\n']
# 1    ['  "blockhash": "00000000000000000002f39baabb00ffeb47dbdb425d5077baa62c47482b7e92",\n']
# 2    ['  "blockhash": "00000000000000000001993b6b5e4e3dac1187820bccc5ab324d6f01c05d6146",\n']
# 3    ['  "blockhash": "000000000000000000055646f272b32b2b844137f215163229aed0099f2a6640",\n']
# 4    ['  "blockhash": "0000000000000000000e360e05cb9d7b238b95cc881726d0519e0449be361d9e",\n']
# 5    ['  "blockhash": "0000000000000000000add9a48ae518c8e1aab061d313cf8c07a69e860c7ec0b",\n']
# 6    ['  "blockhash": "00000000000000000005975f6e8351d800c47eb3ec41b30586b001f382f5e47d",\n']
# 7    ['  "blockhash": "0000000000000000000a5f9662af95174b8ff46df4b7cbae4334283a1465dcb0",\n']
# 8    ['  "blockhash": "0000000000000000000bd59e42336960925a4c465459b6208eebcb22ecfe0839",\n']
# 9    ['  "blockhash": "0000000000000000000190997c460412aab3ed2a260447c896f16f8a3e17dd87",\n']
# Name: blockhash, dtype: object

# %%
blockchain["blockhash"] = blockchain["blockhash"].str[18:82]

# %%
print(blockchain['blockhash'])
# Out:
# 0    0000000000000000000590fc0f3eba193a278534220b2b37e9849e1a770ca959
# 1    00000000000000000002f39baabb00ffeb47dbdb425d5077baa62c47482b7e92
# 2    00000000000000000001993b6b5e4e3dac1187820bccc5ab324d6f01c05d6146
# 3    000000000000000000055646f272b32b2b844137f215163229aed0099f2a6640
# 4    0000000000000000000e360e05cb9d7b238b95cc881726d0519e0449be361d9e
# 5    0000000000000000000add9a48ae518c8e1aab061d313cf8c07a69e860c7ec0b
# 6    00000000000000000005975f6e8351d800c47eb3ec41b30586b001f382f5e47d
# 7    0000000000000000000a5f9662af95174b8ff46df4b7cbae4334283a1465dcb0
# 8    0000000000000000000bd59e42336960925a4c465459b6208eebcb22ecfe0839
# 9    0000000000000000000190997c460412aab3ed2a260447c896f16f8a3e17dd87
# Name: blockhash, dtype: object

# %%
blockchain
# Out:
#   avgfee avgfeerate avgtxsize  \
# 0  12069         15      1000
# 1   2078          2       956
# 2   4082          8       627
# 3  25372         35       981
# 4   5484         11       831
# 5   4076         10       552
# 6   7852         15       680
# 7   8023         16       723
# 8   6225         15       562
# 9   3048          5       703
#
#                                                           blockhash  height  \
# 0  0000000000000000000590fc0f3eba193a278534220b2b37e9849e1a770ca959  700000
# 1  00000000000000000002f39baabb00ffeb47dbdb425d5077baa62c47482b7e92  700001
# 2  00000000000000000001993b6b5e4e3dac1187820bccc5ab324d6f01c05d6146  700002
# 3  000000000000000000055646f272b32b2b844137f215163229aed0099f2a6640  700003
# 4  0000000000000000000e360e05cb9d7b238b95cc881726d0519e0449be361d9e  700004
# 5  0000000000000000000add9a48ae518c8e1aab061d313cf8c07a69e860c7ec0b  700005
# 6  00000000000000000005975f6e8351d800c47eb3ec41b30586b001f382f5e47d  700006
# 7  0000000000000000000a5f9662af95174b8ff46df4b7cbae4334283a1465dcb0  700007
# 8  0000000000000000000bd59e42336960925a4c465459b6208eebcb22ecfe0839  700008
# 9  0000000000000000000190997c460412aab3ed2a260447c896f16f8a3e17dd87  700009
#
#     ins   maxfee maxfeerate maxtxsize medianfee  ... swtotal_weight swtxs  \
# 0  6342  1400000        358     86228      1512  ...        2749806   939
# 1  2435   153000        251     46044       336  ...         679348   423
# 2   729    59549        316     22613      1363  ...         240300   186
# 3   716  2546496        202     35443      1486  ...         181253    90
# 4  1174   283320        477     53046      1323  ...         532137   254
# 5  1924   140826        160     23237      1101  ...         783009   561
# 6   618   173400        192     22173      1275  ...         238306   147
# 7  4141   584712        389     72988      1333  ...        1778025   985
# 8  6130   388224        605     61070      1396  ...        2493668  1850
# 9  2176   164097        155     46079       452  ...         962582   575
#
#          time      total_out total_size total_weight  totalfee   txs  \
# 0  1631333672  4960138797209    1276027      3996622  15388640  1276
# 1  1631333702    21643550568     473624      1433396   1028918   496
# 2  1631333827  2291721978694     159487       461632   1036999   255
# 3  1631333877  2264155720920     128543       373541   3323862   132
# 4  1631334045    42637502244     265366       619369   1749708   320
# 5  1631334474    79354950672     407791      1140049   3008389   739
# 6  1631334600  2292983899306     140867       412274   1625392   208
# 7  1631335351  7100723072452     969331      2630377  10752114  1341
# 8  1631337023  5062345759872    1384758      3997992  15333181  2464
# 9  1631337205   133409776125     496257      1446510   2149090   706
#
#   utxo_increase utxo_size_inc
# 0           186         15021
# 1           738         47985
# 2            75          3969
# 3           330         23618
# 4           129          7715
# 5           413         35140
# 6           378         28800
# 7          2048        156780
# 8          3689        271862
# 9           676         61442
#
# [10 rows x 28 columns]
